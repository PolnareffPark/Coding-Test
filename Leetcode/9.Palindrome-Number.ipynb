# %% [markdown]
# Given an integer x, return true if x is a palindrome, and false otherwise.
#
#
# ---
#
# Example 1:
#
# Input: x = 121
#
# Output: true
#
# Explanation: 121 reads as 121 from left to right and from right to left.
#
# Example 2:
#
# Input: x = -121
#
# Output: false
#
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
#
# Example 3:
#
# Input: x = 10
#
# Output: false
#
# Explanation: Reads 01 from right to left. Therefore it is not a palindrome.
#
# ---
#
# Constraints:
#
# -231 <= x <= 231 - 1

# %%
# 본인 답안

class Solution:
    def isPalindrome(self, x: int) -> bool:
        self.x = x
        listed_x = list(str(x))
        reversed_x = []

        if x<0:
            return False

        for i in range(len(listed_x)):
          reversed_x.append(listed_x[-(i+1)])
        
        reversed_x = "".join(reversed_x)

        if int(reversed_x) == x:
          return True
        else:
          return False

# %%
# 훨씬 짧은 코드가 있습니다.

class Solution:
    def isPalindrome(self, x: int) -> bool:
        orig_str = str(x)
        rev_str = orig_str[::-1] # 리스트를 간단하게 뒤집어서 출력할 수 있습니다.
        # 또는 리스트에 대고 a.reversed() 라고 하면 a 값이 뒤집어져서 저장됩니다.
        return orig_str==rev_str
